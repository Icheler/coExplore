# %%
import os
import shutil

# %%
def file_mover(source_folder, type, number):
    for file_name in os.listdir(source_folder):
        split = file_name.split('_')
        source = f'{source_folder}/{file_name}'
        destination = 'tme_data/sets'
        if split[0] == 'v2':
            destination = f'{destination}/v2_maze/{type}/{number}/{file_name}'
            if os.path.isfile(source):
                shutil.move(source, destination)
                print(f'Moved: {file_name}')
        elif split[0] == 'marty':
            destination = f'{destination}/marty/{type}/{number}/{file_name}'
            if os.path.isfile(source):
                shutil.move(source, destination)
                print(f'Moved: {file_name}')
        elif split[0] == 'map':
            destination = f'{destination}/map_3/{type}/{number}/{file_name}'
            if os.path.isfile(source):
                shutil.move(source, destination)
                print(f'Moved: {file_name}')
        else:
            print(f'Something went wrong while moving file {source}')
            return -1

# %%
def move_all_files():
    for i in range(2, 6):
        source_folder = f'tme_data/coverage/measurements/{i}'
        file_mover(source_folder, 'coverage', i)
        source_folder = f'tme_data/distances/{i}'
        file_mover(source_folder, 'distances', i)

# %%
move_all_files()
# Out:
# Moved: v2_maze_minEuclid_2022-02-24-22:35:49.txt
# Moved: map_3_minEuclid_2022-02-24-21:45:08.yaml
# Moved: v2_maze_minEuclid_2022-02-24-20:25:13.txt
# Moved: v2_maze_minEuclid_2022-02-24-21:33:35.yaml
# Moved: v2_maze_minEuclid_2022-02-24-21:41:59.txt
# Moved: map_3_minEuclid_2022-02-24-21:06:10.txt
# Moved: map_3_minEuclid_2022-02-24-22:44:12.yaml
# Moved: map_3_minEuclid_2022-02-24-20:33:35.txt
# Moved: map_3_minEuclid_2022-02-24-21:06:10.pgm
# Moved: map_3_minEuclid_2022-02-24-22:44:12.txt
# Moved: v2_maze_minEuclid_2022-02-24-21:41:59.pgm
# Moved: map_3_minEuclid_2022-02-24-21:48:46.yaml
# Moved: v2_maze_minEuclid_2022-02-24-20:57:47.txt
# Moved: map_3_minEuclid_2022-02-24-20:00:49.yaml
# Moved: map_3_minEuclid_2022-02-24-21:48:46.pgm
# Moved: map_3_minEuclid_2022-02-24-21:45:08.txt
# Moved: map_3_minEuclid_2022-02-24-20:33:35.pgm
# Moved: map_3_minEuclid_2022-02-24-21:48:46.txt
# Moved: map_3_minEuclid_2022-02-24-21:06:10.yaml
# Moved: v2_maze_minEuclid_2022-02-24-22:35:49.pgm
# Moved: v2_maze_minEuclid_2022-02-24-22:31:17.pgm
# Moved: map_3_minEuclid_2022-02-24-20:00:49.pgm
# Moved: map_3_minEuclid_2022-02-24-22:44:12.pgm
# Moved: map_3_minEuclid_2022-02-24-21:45:08.pgm
# Moved: map_3_minEuclid_2022-02-24-20:33:35.yaml
# Moved: v2_maze_minEuclid_2022-02-24-19:52:26.txt
# Moved: v2_maze_minEuclid_2022-02-24-20:25:13.yaml
# Moved: v2_maze_minEuclid_2022-02-24-20:57:47.pgm
# Moved: v2_maze_minEuclid_2022-02-24-22:31:17.yaml
# Moved: v2_maze_minEuclid_2022-02-24-19:52:26.pgm
# Moved: v2_maze_minEuclid_2022-02-24-21:33:35.txt
# Moved: v2_maze_minEuclid_2022-02-24-20:25:13.pgm
# Moved: v2_maze_minEuclid_2022-02-24-21:33:35.pgm
# Moved: v2_maze_minEuclid_2022-02-24-22:31:17.txt
# Moved: v2_maze_minEuclid_2022-02-24-20:57:47.yaml
# Moved: v2_maze_minEuclid_2022-02-24-19:52:26.yaml
# Moved: v2_maze_minEuclid_2022-02-24-21:41:59.yaml
# Moved: v2_maze_minEuclid_2022-02-24-22:35:49.yaml
# Moved: map_3_minEuclid_2022-02-24-20:00:49.txt
# Moved: v2_maze_minEuclid_2022-02-24|19:52:26.txt
# Moved: v2_maze_minEuclid_2022-02-24|21:33:36.txt
# Moved: v2_maze_minEuclid_2022-02-24|20:57:47.txt
# Moved: map_3_minEuclid_2022-02-24|20:33:36.txt
# Moved: v2_maze_minEuclid_2022-02-24|21:41:59.txt
# Moved: map_3_minEuclid_2022-02-24|22:44:12.txt
# Moved: map_3_minEuclid_2022-02-24|21:06:10.txt
# Moved: map_3_minEuclid_2022-02-24|20:00:49.txt
# Moved: v2_maze_minEuclid_2022-02-24|22:35:49.txt
# Moved: v2_maze_minEuclid_2022-02-24|20:25:13.txt
# Moved: map_3_minEuclid_2022-02-24|21:48:46.txt
# Moved: map_3_minEuclid_2022-02-24|21:45:08.txt
# Moved: v2_maze_minEuclid_2022-02-24|22:31:17.txt
# Moved: v2_maze_minEuclid_2022-02-24-21:09:33.txt
# Moved: v2_maze_minEuclid_2022-02-24-21:54:43.yaml
# Moved: v2_maze_minEuclid_2022-02-24-20:05:32.pgm
# Moved: map_3_minEuclid_2022-02-24-21:58:34.pgm
# Moved: v2_maze_minEuclid_2022-02-24-20:05:32.txt
# Moved: v2_maze_minEuclid_2022-02-24-21:52:51.yaml
# Moved: v2_maze_minEuclid_2022-02-24-21:52:51.pgm
# Moved: map_3_minEuclid_2022-02-24-21:16:17.pgm
# Moved: map_3_minEuclid_2022-02-24-21:58:34.txt
# Moved: v2_maze_minEuclid_2022-02-24-21:54:43.pgm
# Moved: map_3_minEuclid_2022-02-24-20:12:16.pgm
# Moved: v2_maze_minEuclid_2022-02-24-21:52:51.txt
# Moved: map_3_minEuclid_2022-02-24-21:16:17.txt
# Moved: map_3_minEuclid_2022-02-24-21:56:47.pgm
# Moved: v2_maze_minEuclid_2022-02-24-20:37:23.yaml
# Moved: v2_maze_minEuclid_2022-02-24-20:37:23.txt
# Moved: map_3_minEuclid_2022-02-24-20:42:02.yaml
# Moved: v2_maze_minEuclid_2022-02-24-20:05:32.yaml
# Moved: map_3_minEuclid_2022-02-24-20:12:16.txt
# Moved: v2_maze_minEuclid_2022-02-24-21:09:33.pgm
# Moved: map_3_minEuclid_2022-02-24-21:56:47.yaml
# Moved: v2_maze_minEuclid_2022-02-24-20:37:23.pgm
# Moved: map_3_minEuclid_2022-02-24-21:58:34.yaml
# Moved: map_3_minEuclid_2022-02-24-21:16:17.yaml
# Moved: map_3_minEuclid_2022-02-24-20:42:02.txt
# Moved: v2_maze_minEuclid_2022-02-24-21:54:43.txt
# Moved: map_3_minEuclid_2022-02-24-20:42:02.pgm
# Moved: map_3_minEuclid_2022-02-24-20:12:16.yaml
# Moved: v2_maze_minEuclid_2022-02-24-21:09:33.yaml
# Moved: map_3_minEuclid_2022-02-24-21:56:47.txt
# Moved: map_3_minEuclid_2022-02-24|21:56:47.txt
# Moved: v2_maze_minEuclid_2022-02-24|20:37:23.txt
# Moved: v2_maze_minEuclid_2022-02-24|20:05:32.txt
# Moved: v2_maze_minEuclid_2022-02-24|21:09:33.txt
# Moved: v2_maze_minEuclid_2022-02-24|21:52:51.txt
# Moved: map_3_minEuclid_2022-02-24|21:58:34.txt
# Moved: map_3_minEuclid_2022-02-24|21:16:17.txt
# Moved: map_3_minEuclid_2022-02-24|20:12:16.txt
# Moved: map_3_minEuclid_2022-02-24|20:42:02.txt
# Moved: v2_maze_minEuclid_2022-02-24|21:54:43.txt
# Moved: v2_maze_minEuclid_2022-02-24-22:01:13.pgm
# Moved: map_3_minEuclid_2022-02-24-21:22:22.yaml
# Moved: v2_maze_minEuclid_2022-02-24-21:19:06.txt
# Moved: map_3_minEuclid_2022-02-24-22:08:06.pgm
# Moved: v2_maze_minEuclid_2022-02-24-20:14:45.pgm
# Moved: map_3_minEuclid_2022-02-24-21:22:22.pgm
# Moved: v2_maze_minEuclid_2022-02-24-20:43:56.pgm
# Moved: map_3_minEuclid_2022-02-24-21:22:22.txt
# Moved: map_3_minEuclid_2022-02-24-20:49:04.yaml
# Moved: v2_maze_minEuclid_2022-02-24-20:14:45.yaml
# Moved: v2_maze_minEuclid_2022-02-24-22:01:13.yaml
# Moved: v2_maze_minEuclid_2022-02-24-22:04:38.pgm
# Moved: v2_maze_minEuclid_2022-02-24-20:43:56.txt
# Moved: map_3_minEuclid_2022-02-24-20:49:04.pgm
# Moved: v2_maze_minEuclid_2022-02-24-20:43:56.yaml
# Moved: map_3_minEuclid_2022-02-24-22:08:06.yaml
# Moved: v2_maze_minEuclid_2022-02-24-22:04:38.yaml
# Moved: map_3_minEuclid_2022-02-24-20:19:54.yaml
# Moved: map_3_minEuclid_2022-02-24-20:19:54.txt
# Moved: map_3_minEuclid_2022-02-24-20:49:04.txt
# Moved: v2_maze_minEuclid_2022-02-24-22:04:38.txt
# Moved: v2_maze_minEuclid_2022-02-24-22:01:13.txt
# Moved: v2_maze_minEuclid_2022-02-24-20:14:45.txt
# Moved: map_3_minEuclid_2022-02-24-22:08:06.txt
# Moved: v2_maze_minEuclid_2022-02-24-21:19:06.yaml
# Moved: map_3_minEuclid_2022-02-24-20:19:54.pgm
# Moved: v2_maze_minEuclid_2022-02-24-21:19:06.pgm
# Moved: map_3_minEuclid_2022-02-24|22:08:06.txt
# Moved: map_3_minEuclid_2022-02-24|20:49:04.txt
# Moved: v2_maze_minEuclid_2022-02-24|22:01:13.txt
# Moved: v2_maze_minEuclid_2022-02-24|20:43:56.txt
# Moved: v2_maze_minEuclid_2022-02-24|22:04:38.txt
# Moved: map_3_minEuclid_2022-02-24|21:22:22.txt
# Moved: map_3_minEuclid_2022-02-24|20:19:54.txt
# Moved: v2_maze_minEuclid_2022-02-24|21:19:06.txt
# Moved: v2_maze_minEuclid_2022-02-24|20:14:45.txt
# Moved: v2_maze_minEuclid_2022-02-24-21:27:29.txt
# Moved: map_3_minEuclid_2022-02-24-22:22:28.pgm
# Moved: map_3_minEuclid_2022-02-24-21:31:57.yaml
# Moved: v2_maze_minEuclid_2022-02-24-21:27:29.yaml
# Moved: v2_maze_minEuclid_2022-02-24-22:13:37.txt
# Moved: v2_maze_minEuclid_2022-02-24-20:51:40.pgm
# Moved: v2_maze_minEuclid_2022-02-24-22:17:59.pgm
# Moved: map_3_minEuclid_2022-02-24-20:56:04.txt
# Moved: map_3_minEuclid_2022-02-24-22:26:49.pgm
# Moved: v2_maze_minEuclid_2022-02-24-20:21:45.yaml
# Moved: v2_maze_minEuclid_2022-02-24-20:21:45.pgm
# Moved: map_3_minEuclid_2022-02-24-20:23:34.txt
# Moved: map_3_minEuclid_2022-02-24-20:23:34.pgm
# Moved: map_3_minEuclid_2022-02-24-20:23:34.yaml
# Moved: v2_maze_minEuclid_2022-02-24-20:51:40.yaml
# Moved: v2_maze_minEuclid_2022-02-24-22:13:37.pgm
# Moved: v2_maze_minEuclid_2022-02-24-22:17:59.yaml
# Moved: map_3_minEuclid_2022-02-24-22:22:28.txt
# Moved: map_3_minEuclid_2022-02-24-21:31:57.pgm
# Moved: map_3_minEuclid_2022-02-24-20:56:04.pgm
# Moved: v2_maze_minEuclid_2022-02-24-20:51:40.txt
# Moved: map_3_minEuclid_2022-02-24-22:22:28.yaml
# Moved: v2_maze_minEuclid_2022-02-24-20:21:45.txt
# Moved: map_3_minEuclid_2022-02-24-21:31:57.txt
# Moved: map_3_minEuclid_2022-02-24-22:26:49.txt
# Moved: v2_maze_minEuclid_2022-02-24-22:17:59.txt
# Moved: v2_maze_minEuclid_2022-02-24-21:27:29.pgm
# Moved: map_3_minEuclid_2022-02-24-22:26:49.yaml
# Moved: v2_maze_minEuclid_2022-02-24-22:13:37.yaml
# Moved: map_3_minEuclid_2022-02-24-20:56:04.yaml
# Moved: map_3_minEuclid_2022-02-24|22:22:28.txt
# Moved: v2_maze_minEuclid_2022-02-24|20:21:45.txt
# Moved: map_3_minEuclid_2022-02-24|21:31:57.txt
# Moved: v2_maze_minEuclid_2022-02-24|21:27:29.txt
# Moved: map_3_minEuclid_2022-02-24|20:23:34.txt
# Moved: v2_maze_minEuclid_2022-02-24|20:51:40.txt
# Moved: v2_maze_minEuclid_2022-02-24|22:17:59.txt
# Moved: map_3_minEuclid_2022-02-24|22:26:49.txt
# Moved: v2_maze_minEuclid_2022-02-24|22:13:37.txt
# Moved: map_3_minEuclid_2022-02-24|20:56:04.txt
